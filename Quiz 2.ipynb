# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from jupyterthemes  import jtplot

jtplot.style(theme='monokai')
# Out:
# C:\Users\Kyujin\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# C:\Users\Kyujin\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
survivedP= df[df['Survived']==1]['Pclass'].value_counts()
deadP=df[df['Survived']==0]['Pclass'].value_counts()
survivedP
deadP
dfP
# Out:
#             1   2    3
# Survived  136  87  119
# Dead       80  97  372

# %%
dfP= pd.DataFrame([survivedP, deadP])
dfP.index = ['Survived', 'Dead']
dfP.plot(kind='bar',stacked=True)

# %%
subset_E=df[['Embarked','Survived']]
subset_E
survivedE= df[df['Survived']==1]['Embarked'].value_counts()
deadE=df[df['Survived']==0]['Embarked'].value_counts()
survivedE
deadE
dfE
# Out:
#             S   C   Q
# Survived  217  93  30
# Dead      427  75  47

# %%
dfE= pd.DataFrame([survivedE, deadE])
dfE.index = ['Survived', 'Dead']
dfE.plot(kind='bar',stacked=True)

# %%
survivedS= df[df['Survived']==1]['Sex'].value_counts()
deadS=df[df['Survived']==0]['Sex'].value_counts()
survivedS
deadS
dfS
# Out:
#           female  male
# Survived     233   109
# Dead          81   468

# %%
dfS= pd.DataFrame([survivedS, deadS])
dfS.index = ['Survived', 'Dead']
dfS.plot(kind='bar',stacked=True)

# %%
survivedA= df[df['Survived']==1]['Age'].value_counts()
deadA=df[df['Survived']==0]['Age'].value_counts()
survivedA
deadA
# Out:
# 21.0    19
# 28.0    18
# 25.0    17
# 18.0    17
# 22.0    16
# 19.0    16
# 30.0    15
# 24.0    15
# 29.0    12
# 20.0    12
# 26.0    12
# 36.0    11
# 16.0    11
# 23.0    10
# 32.0     9
# 31.0     9
# 39.0     9
# 34.0     9
# 33.0     9
# 47.0     8
# 45.0     7
# 42.0     7
# 40.0     7
# 2.0      7
# 35.0     7
# 27.0     7
# 17.0     7
# 38.0     6
# 44.0     6
# 9.0      6
#         ..
# 10.0     2
# 64.0     2
# 58.0     2
# 70.0     2
# 8.0      2
# 59.0     2
# 57.0     2
# 71.0     2
# 62.0     2
# 45.5     2
# 60.0     2
# 30.5     2
# 40.5     2
# 56.0     2
# 49.0     2
# 24.5     1
# 6.0      1
# 34.5     1
# 15.0     1
# 66.0     1
# 55.0     1
# 3.0      1
# 23.5     1
# 20.5     1
# 14.5     1
# 74.0     1
# 32.5     1
# 36.5     1
# 55.5     1
# 70.5     1
# Name: Age, Length: 77, dtype: int64

# %%
dfA= pd.DataFrame([survivedA, deadA])
dfA.index = ['Survived', 'Dead']
dfA
# Out:
#           0.42   0.67   0.75   0.83   0.92   1.00   2.00   3.00   4.00   \
# Survived    1.0    1.0    2.0    2.0    1.0    5.0    3.0    5.0    7.0
# Dead        NaN    NaN    NaN    NaN    NaN    2.0    7.0    1.0    3.0
#
#           5.00   ...  62.00  63.00  64.00  65.00  66.00  70.00  70.50  71.00  \
# Survived    4.0  ...    2.0    2.0    NaN    NaN    NaN    NaN    NaN    NaN
# Dead        NaN  ...    2.0    NaN    2.0    3.0    1.0    2.0    1.0    2.0
#
#           74.00  80.00
# Survived    NaN    1.0
# Dead        1.0    NaN
#
# [2 rows x 88 columns]

# %%
dfA.plot()
