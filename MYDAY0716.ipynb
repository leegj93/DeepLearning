# %%
## Decision Tree

import pandas as pd
import numpy as np

# %%
train=pd.read_csv("data/titanic/train.csv")
test=pd.read_csv("data/titanic/test.csv")

# %%
train['Age_mean']=train['Age']
train['Age_mean'].fillna(train["Age_mean"].mean(), inplace = True)
test['Age_mean']=test['Age']
test['Age_mean'].fillna(test["Age_mean"].mean(), inplace = True)

# %%
train['Age_mean'].isnull().sum()
# Out:
# 0

# %%
train['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train['Gender']=(train['Sex']=='Female')
test['Gender']=(test['Sex']=='Female')

# %%
test['Gender']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 388    False
# 389    False
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# 400    False
# 401    False
# 402    False
# 403    False
# 404    False
# 405    False
# 406    False
# 407    False
# 408    False
# 409    False
# 410    False
# 411    False
# 412    False
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: Gender, Length: 418, dtype: bool

# %%
train['Embarked'].value_counts()
train['Embarked'].isnull().sum()## 2개
# Out:
# 2

# %%
train['Embarked_S']= train['Embarked']=='S'
train['Embarked_C']= train['Embarked']=='C'
train['Embarked_Q']= train['Embarked']=='Q'

# %%
train[['Embarked_S','Embarked_C','Embarked_Q']]
# Out:
#      Embarked_S  Embarked_C  Embarked_Q
# 0          True       False       False
# 1         False        True       False
# 2          True       False       False
# 3          True       False       False
# 4          True       False       False
# 5         False       False        True
# 6          True       False       False
# 7          True       False       False
# 8          True       False       False
# 9         False        True       False
# 10         True       False       False
# 11         True       False       False
# 12         True       False       False
# 13         True       False       False
# 14         True       False       False
# 15         True       False       False
# 16        False       False        True
# 17         True       False       False
# 18         True       False       False
# 19        False        True       False
# 20         True       False       False
# 21         True       False       False
# ...

# %%
test['Embarked_S']= test['Embarked']=='S'
test['Embarked_C']= test['Embarked']=='C'
test['Embarked_Q']= test['Embarked']=='Q'

# %%
train['FamilySize']=train['SibSp']+train['Parch']+1
train['FamilySize'].value_counts()
train['Family']=train['FamilySize']
#대가족(5):L 소가족(1):S  중가족(2~4): M
train.loc[train['FamilySize']==1, 'Family']='S'
train.loc[(train['FamilySize']>1) & (train['FamilySize']<4), 'Family']='M'
train.loc[train['FamilySize']>4, 'Family']='L'
#대가족(5):L 소가족(1):S  중가족(2~4): M
test.loc[train['FamilySize']==1, 'Family']='S'
test.loc[(train['FamilySize']>1) & (test['FamilySize']<4), 'Family']='M'
test.loc[train['FamilySize']>4, 'Family']='L'

test['FamilySize']=test['SibSp']+test['Parch']+1
test['FamilySize'].value_counts()
test['Family']=test['FamilySize']

# %%
test[['Family','FamilySize']]
# Out:
#      Family  FamilySize
# 0         1           1
# 1         2           2
# 2         1           1
# 3         1           1
# 4         3           3
# 5         1           1
# 6         1           1
# 7         3           3
# 8         1           1
# 9         3           3
# 10        1           1
# 11        1           1
# 12        2           2
# 13        2           2
# 14        2           2
# 15        2           2
# 16        1           1
# 17        1           1
# 18        2           2
# 19        1           1
# 20        2           2
# 21        2           2
# 22        1           1
# 23        2           2
# 24        5           5
# 25        2           2
# 26        2           2
# 27        1           1
# 28        1           1
# 29        3           3
# ..      ...         ...
# 388       1           1
# 389       5           5
# 390       1           1
# 391       2           2
# 392       3           3
# 393       1           1
# ...

# %%
train['Family_S']=train['Family']=='S'
train['Family_M']=train['Family']=='M'
train['Family_L']=train['Family']=='L'

test['Family_S']=test['Family']=='S'
test['Family_M']=test['Family']=='M'
test['Family_L']=test['Family']=='L'

# %%
train[['Family_S','Family_M','Family_L','Family','FamilySize']]
# Out:
#      Family_S  Family_M  Family_L Family  FamilySize
# 0       False      True     False      M           2
# 1       False      True     False      M           2
# 2        True     False     False      S           1
# 3       False      True     False      M           2
# 4        True     False     False      S           1
# 5        True     False     False      S           1
# 6        True     False     False      S           1
# 7       False     False      True      L           5
# 8       False      True     False      M           3
# 9       False      True     False      M           2
# 10      False      True     False      M           3
# 11       True     False     False      S           1
# 12       True     False     False      S           1
# 13      False     False      True      L           7
# 14       True     False     False      S           1
# 15       True     False     False      S           1
# 16      False     False      True      L           6
# ...

# %%
train['Pclass']=train['Pclass'].astype('category')
train['Pclass'].dtypes
# Out:
# CategoricalDtype(categories=[1, 2, 3], ordered=False)

# %%
fn=['Gender', 'Age_mean','Embarked_S','Embarked_C','Embarked_Q','Family_S','Family_M','Family_L']
X_train=train[fn]
X_train.head()
Y_label=train['Survived']
X_test= test[fn]

# %%
from sklearn.tree import DecisionTreeClassifier
model= DecisionTreeClassifier(max_depth=8)#연산량이 많음
model
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=8,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
model.fit(X_train, Y_label)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=8,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
kfold=KFold(n_splits=100, shuffle=True,random_state=2019)#(n_splits=3, random_state=None, shuffle=False)
kfold
# Out:
# KFold(n_splits=100, random_state=2019, shuffle=True)

# %%
score= cross_val_score(model, X_train, Y_label, cv=kfold, scoring='accuracy')

print(score)
np.mean(score)
# Out:
# [0.66666667 0.66666667 0.44444444 0.66666667 0.66666667 0.66666667
#  0.66666667 0.33333333 0.88888889 0.55555556 0.55555556 0.55555556
#  0.66666667 0.33333333 0.77777778 0.55555556 0.44444444 0.66666667
#  0.44444444 0.55555556 0.55555556 0.66666667 0.66666667 0.77777778
#  0.55555556 0.55555556 0.55555556 0.77777778 0.77777778 0.77777778
#  0.55555556 0.77777778 0.77777778 0.66666667 0.66666667 0.33333333
#  0.55555556 0.44444444 0.66666667 0.66666667 0.77777778 0.55555556
#  0.77777778 0.77777778 0.55555556 0.55555556 0.44444444 0.77777778
#  0.44444444 0.66666667 0.66666667 0.66666667 0.88888889 0.66666667
#  0.33333333 0.44444444 0.66666667 0.88888889 0.55555556 0.33333333
#  0.33333333 0.55555556 0.66666667 0.44444444 0.77777778 0.66666667
#  0.55555556 0.66666667 0.66666667 0.77777778 0.33333333 0.77777778
#  0.44444444 0.88888889 0.55555556 1.         0.77777778 0.44444444
#  0.77777778 0.77777778 0.66666667 0.77777778 0.77777778 0.77777778
# ...

# %%
prediction=model.predict(X_test)
prediction.shape
# Out:
# (418,)

# %%
test['Survived']=prediction

# %%
submission=test[['PassengerId','Survived']]
submission.to_csv('submission.csv',index=False)

# %%
# urllib:url을 다루는 모듈의 집합
# urllib.request: 웹데이터 접근

import urllib.request
url = "https://www.google.com/images/branding/googlelogo/2x/googlelogo_color_272x92dp.png"
sname = "test.png"
urllib.request.urlretrieve(url, sname)
print('저장됐습니다.')
# Out:
# 저장됐습니다.

# %%
# urlopen() 함수는 메모리 저장

import urllib.request
url = "https://www.google.com/images/branding/googlelogo/2x/googlelogo_color_272x92dp.png"
sname = "test2.png"
mem=urllib.request.urlopen(url).read()## 메모리 저장
with open(sname, mode ="wb") as f:
    f.write(mem)
    print('이미지 저장')
# Out:
# 이미지 저장

# %%
# www.kma.go.kr/weather/forecast/mid-term-rss3.jsp
#웹문서 형식: json, html(미구조 문서 => 해석 어려움), xml, rdf....

# %%
www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?'stnId':'108'

# %%
import urllib.parse
values={'stnId':'184'}
params= urllib.parse.urlencode(values)
API = 'http://www.weather.go.kr/weather/forecast/mid-term-rss3.jsp?'
url = API + '?' + params
data=urllib.request.urlopen(url).read()
text=data.decode("utf-8")
print(text)
# data.decode('utf-8')
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2019년 07월 16일 (화)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2019년 07월 16일 (화)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# 	<header>
# 		<title>전국 육상중기예보</title>
# 		<tm>201907160600</tm>
# 		<wf><![CDATA[장마전선의 영향으로 19일은 충청도와 남부지방, 제주도에 장맛비가 오겠습니다.<br />그 밖의 날은 고기압의 가장자리에 들어 구름많은 날이 많겠습니다.<br />기온은 평년(최저기온: 20~24℃, 최고기온: 27~32℃)과 비슷하겠습니다.<br />강수량은 평년(4~17mm)보다 서울.경기도와 강원도는 적겠고, 그 밖의 지방은 비슷하거나 조금 많겠습니다.<br /><br />* 열대저압부(TD)의 발달 여부와 북태평양고기압의 확장 정도에 따라 장마전선의 위치와 강수 영역이 달라질 수 있으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.]]></wf>
# ...

# %%
from bs4 import BeautifulSoup

html="""
<html>
<body>
<h1>멀티캠퍼스</h1>
<h1>역삼동</h1>
<p>1003호</p>
<p>빅데이터 설계반</p>
</body>
</html>"""

soup=BeautifulSoup(html,'html.parser')
soup.p
p1=soup.html.body.p#내용만 출력
p1.next_sibling.next_sibling
#api reference: www.crummy.com/software/BeautifulSoup/bs4/doc
# Out:
# <p>빅데이터 설계반</p>

# %%
html="""
<html>
<body>
<h1 id ="title">스크래핑?</h1>
<p>웹페이지 분석</p>
<p id = "myid">원하는 부분 추출</p>
</body>
</html>"""

#html 분석

soup=BeautifulSoup(html, 'html5lib')
title=soup.find(id='title')
myid=soup.find(id='myid')
print(title.string)
print(myid.string)
print(soup.find("p").string)
# Out:
# 스크래핑?
# 원하는 부분 추출
# 웹페이지 분석

# %%
html="""
<html><body>
<ul>
<li><a href="https://www.naver.com">naver</a></li>
<li><a href="https://www.daum.com">daum</a></li>
<ul>
</body></html>
"""

soup=BeautifulSoup(html, 'html.parser')
links=soup.find_all("a")
for link in links:
    href=link.attrs['href']
    text=link.string
    print(text, '===>', href)
# Out:
# naver ===> https://www.naver.com
# daum ===> https://www.daum.com

# %%
#기상청으로 이동해서 title 태크 내용 추출
# wf 태그 내용 추출
# tmn, tmx 값 추출

import urllib.parse
values={'stnId':'184'}
params= urllib.parse.urlencode(values)
API = 'http://www.weather.go.kr/weather/forecast/mid-term-rss3.jsp'
url = API + '?' + params
data=urllib.request.urlopen(url).read()
text=data.decode("utf-8")
print(text)
# data.decode('utf-8')
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_07.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2019년 07월 16일 (화)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>제주도 육상 중기예보 - 2019년 07월 16일 (화)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_07.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_07.jsp</guid>
# <description>
# 	<header>
# 		<title>제주도 육상중기예보</title>
# 		<tm>201907160600</tm>
# ...

# %%
soup = BeautifulSoup(text, 'html.parser')
soup
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_07.jsp
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubdate>2019년 07월 16일 (화)요일 06:00</pubdate>
# <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>제주도 육상 중기예보 - 2019년 07월 16일 (화)요일 06:00 발표</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_07.jsp
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_07.jsp</guid>
# <description>
# <header>
# <title>제주도 육상중기예보</title>
# <tm>201907160600</tm>
# <wf><![CDATA[19일에 장마전선의 영향으로 비가 오겠고, 그 밖의 날은 고기압 가장자리에 들어 구름이 많겠습니다.<br />기온은 평년(최저기온: 24~25℃, 최고기온: 29~30℃)과 비슷하겠습니다. 강수량은 평년(4~10mm)보다 많겠습니다.<br />바다의 물결은 제주도전해상과 남해서부먼바다에서 19~21일에 1.0~4.0m로 높게 일고, 그 밖의 날은 1.0~2.0m로 일겠습니다.<br /><br />* 열대저압부(TD)의 발달 여부와 북태평양고기압의 확장 정도에 따라 장마전선의 위치와 강수 영역이 달라질 수 있으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.]]></wf>
# </header>
# ...

# %%
titles=soup.find_all("title")
for link in titles:
    title_text=link.string
    print(title_text)
# Out:
# 기상청 육상 중기예보
# 제주도 육상 중기예보 - 2019년 07월 16일 (화)요일 06:00 발표
# 제주도 육상중기예보

# %%
wfA=[]
wfs =soup.find_all("wf")
for link in wfs:
    wf_text=link.string
    wfA.append(link.string)

# %%
tmnA=[]
tmns =soup.find_all("tmn")
for link in tmns:
    tmn_text=link.string
    tmnA.append(link.string)

# %%
tmxA=[]
tmxs =soup.find_all("tmx")
for link in tmxs:
    tmx_text=link.string
    tmxA.append(link.string)

# %%
dfn=pd.DataFrame(tmnA)
dfx=pd.DataFrame(tmxA)

# %%
dfT=pd.concat([dfn,dfx],axis=1)

# %%
dfT
# Out:
#      0   0
# 0   24  29
# 1   24  29
# 2   26  31
# 3   26  31
# 4   26  30
# 5   26  30
# 6   25  30
# 7   25  30
# 8   25  30
# 9   25  30
# 10  25  31
# 11  24  31
# 12  24  31
# 13  24  28
# 14  24  28
# 15  25  29
# 16  25  29
# 17  25  28
# 18  25  28
# 19  25  29
# 20  25  29
# 21  25  29
# 22  25  29
# 23  25  29
# 24  24  30
# 25  25  30
# 26  24  29
# 27  24  29
# 28  24  29
# 29  24  29
# ..  ..  ..
# 61  24  28
# 62  24  29
# 63  24  29
# 64  24  30
# 65  23  24
# 66  23  24
# 67  24  25
# 68  24  25
# 69  24  25
# 70  24  25
# 71  24  25
# 72  24  25
# 73  24  25
# 74  24  25
# 75  24  25
# 76  24  25
# 77  24  25
# 78  23  28
# 79  23  28
# 80  23  27
# 81  23  27
# 82  23  28
# 83  23  28
# 84  23  27
# 85  23  27
# 86  22  27
# 87  22  27
# 88  23  28
# 89  23  29
# 90  23  29
#
# [91 rows x 2 columns]
