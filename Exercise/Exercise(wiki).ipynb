# %%
from bs4 import BeautifulSoup
import urllib.request as req


#mw-content-text > div > ul:nth-child(6) > li > b > a


url="https://ko.wikisource.org/wiki/%EC%A0%80%EC%9E%90:%EC%9C%A4%EB%8F%99%EC%A3%BC"
res=req.urlopen(url)
soup=BeautifulSoup(res, "html.parser")
print(soup.select("#mw-content-text > div " ))
# Out:
# [<div class="mw-parser-output"><table style="width:100%; margin-bottom:5px; border:1px solid #BEA2A2; background:#E4D8D8;">
# <tbody><tr>
# <td style="width:30%;">←<a href="/wiki/%EB%B6%84%EB%A5%98:%EC%A0%80%EC%9E%90_%E3%85%87" title="분류:저자 ㅇ">분류:저자 ㅇ</a><br/>←<a href="/wiki/%EB%B6%84%EB%A5%98:%EC%9D%BC%EC%A0%9C_%EA%B0%95%EC%A0%90%EA%B8%B0%EC%9D%98_%EC%A0%80%EC%9E%90" title="분류:일제 강점기의 저자">분류:일제 강점기의 저자</a>
# </td>
# <td style="width:45%; text-align:center;"><span style="font-size:115%;"><b>윤동주</b></span><br/>尹東柱<br/>(1917년 ~ 1945년)
# </td>
# <td style="width:25%;">
# </td></tr></tbody></table>
# <table style="width:100%; border-bottom:1px solid #A88; background:#FFFBFC;">
# <tbody><tr>
# ...

# %%
print(soup.select("#mw-content-text > div > ul:nth-child(6)" ))
# Out:
# [<ul><li><b><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C" title="하늘과 바람과 별과 시">하늘과 바람과 별과 시</a></b> (<a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C_(1955%EB%85%84)" title="하늘과 바람과 별과 시 (1955년)">증보판</a>)
# <ul><li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EC%84%9C%EC%8B%9C" title="하늘과 바람과 별과 시/서시">서시</a></li>
# <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EC%9E%90%ED%99%94%EC%83%81" title="하늘과 바람과 별과 시/자화상">자화상</a></li>
# <li><a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C/%EC%86%8C%EB%85%84" title="하늘과 바람과 별과 시/소년">소년</a></li>
# ...

# %%
print(soup.select("#mw-content-text > div > ul:nth-child(6) > li > b > a" ))
# Out:
# [<a href="/wiki/%ED%95%98%EB%8A%98%EA%B3%BC_%EB%B0%94%EB%9E%8C%EA%B3%BC_%EB%B3%84%EA%B3%BC_%EC%8B%9C" title="하늘과 바람과 별과 시">하늘과 바람과 별과 시</a>]

# %%
myList=soup.select("#mw-content-text > div > ul:nth-child(6) > li > b > a" )
print(myList[0].string)
# Out:
# 하늘과 바람과 별과 시

# %%
html="""
<ul id="books">
<li id="b1">상실의 시대</li>
<li id="b2">데미안</li>
<li id="b3">이방인</li>
<li id="b4">태백산맥</li>
<li id="b5">어린왕자</li>
</ul>
"""

# %%
soup=BeautifulSoup(html, 'html.parser')
soup
# Out:
# <ul id="books">
# <li id="b1">상실의 시대</li>
# <li id="b2">데미안</li>
# <li id="b3">이방인</li>
# <li id="b4">태백산맥</li>
# <li id="b5">어린왕자</li>
# </ul>

# %%
sel=lambda q:print(soup.select_one(q).string)
#람다합수 이름: sel, 인자:q
# 위 구문의 의미? sel 함수를 호출할때 전달되는 인자(css 선택)

# %%
#태백산맥을 추출하는 다양한 방법
sel('#b4')
sel('li#b4')
sel('ul li#b4')
sel('#books #b4')
sel('#books > #b4')
sel("li[id='b4']")
sel("li:nth-child(4)")
sel("li:nth-of-type(4)")

soup.select("li")[3].string
print('='*40)
soup.find_all("li")[3].string
# Out:
# 태백산맥
# 태백산맥
# 태백산맥
# 태백산맥
# 태백산맥
# 태백산맥
# 태백산맥
# 태백산맥
# ...
# '태백산맥'

# %% [markdown]
# ```#question-summary-57067264 > div.summary > h3 > a```

# %%
from urllib.request import urlopen
page= urlopen("https://stackoverflow.com/questions/tagged/python")
document=page.read()
soup=BeautifulSoup(document, 'html.parser')
questions=soup.find(id="questions")
questions_list=questions.find_all("a", class_="question-hyperlink")
for questions in questions_list:
    print(questions.get_text())
#     print(questions.string)

    print('http://stackoverflow.com'+questions.get('href'))
    print('='*40)
# Out:
# how can i split a URL and save into the 3 different variables
# http://stackoverflow.com/questions/57067736/how-can-i-split-a-url-and-save-into-the-3-different-variables
# ...
# Open interactive form in using selenium
# http://stackoverflow.com/questions/57067718/open-interactive-form-in-using-selenium
# ...
# How to make website login page using Python in the back end?
# http://stackoverflow.com/questions/57067717/how-to-make-website-login-page-using-python-in-the-back-end
# ...
# how to read data by using pywinusb in python
# http://stackoverflow.com/questions/57067692/how-to-read-data-by-using-pywinusb-in-python
# ...
# Does a functions __get__ method act like a decorator?
# http://stackoverflow.com/questions/57067691/does-a-functions-get-method-act-like-a-decorator
# ...
# geopandas plotting with legend filled up with slash lines
# http://stackoverflow.com/questions/57067623/geopandas-plotting-with-legend-filled-up-with-slash-lines
# ...
# why “RuntimeError CUDA out of memory” in testing?
# ...

# %%
page1= urlopen("https://www.rottentomatoes.com/")
document1=page1.read()
soup1=BeautifulSoup(document1, 'html.parser')
movies=soup1.find(id="homepage-top-box-office")
movies
movies_list=movies.find_all("td", class_="middle_col")
# movies_link=movies_list.get("a")
print(movies_list)
# print(movies_link)
for movies in movies_list:
    print(movies.get_text())
#     movies_link=movies_list.get("a")
#     print(movies_link)
    print('https://www.rottentomatoes.com'+ movies.find("a").get('href'))
    print('='*40)
# Out:
# [<td class="middle_col">
# <a href="/m/spider_man_far_from_home">Spider-Man: Far From Home</a>
# </td>, <td class="middle_col">
# <a href="/m/toy_story_4">Toy Story 4</a>
# </td>, <td class="middle_col">
# <a href="/m/crawl_2019">Crawl</a>
# </td>, <td class="middle_col">
# <a href="/m/stuber">Stuber</a>
# </td>, <td class="middle_col">
# <a href="/m/yesterday_2019">Yesterday</a>
# </td>, <td class="middle_col">
# <a href="/m/aladdin">Aladdin</a>
# </td>, <td class="middle_col">
# <a href="/m/annabelle_comes_home">Annabelle Comes Home</a>
# </td>, <td class="middle_col">
# <a href="/m/midsommar">Midsommar</a>
# </td>, <td class="middle_col">
# <a href="/m/the_secret_life_of_pets_2">The Secret Life of Pets 2</a>
# </td>, <td class="middle_col">
# <a href="/m/men_in_black_international">Men in Black International</a>
# </td>]
#
# Spider-Man: Far From Home
#
# https://www.rottentomatoes.com/m/spider_man_far_from_home
# ...
#
# Toy Story 4
#
# https://www.rottentomatoes.com/m/toy_story_4
# ...
#
# ...
